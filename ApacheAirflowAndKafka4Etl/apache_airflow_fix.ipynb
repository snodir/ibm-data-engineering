# %%
import sys
print(sys.platform)
print(sys.version)
print(sys.executable)
print(sys.modules)
print(globals())
# Out:
# win32
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# c:\Users\user\ProgrammingProjects\Coursera\IBM_DE\ibm-data-engineering\venv312_ibmde\Scripts\python.exe
# ...

# %%
import sys
# Make sure nothing stale is cached
for mod in list(sys.modules):
    if mod.startswith("airflow"):
        del sys.modules[mod]

import airflow.sdk
print("Loaded from:", airflow.sdk.__file__)
print("Has ObjectStoragePath:", hasattr(airflow.sdk, "ObjectStoragePath"))
print([n for n in dir(airflow.sdk) if "Storage" in n or "Object" in n])
# Out:
# c:\Users\user\ProgrammingProjects\Coursera\IBM_DE\ibm-data-engineering\venv312_ibmde\Lib\site-packages\airflow\__init__.py:47: RuntimeWarning: Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority.
#   warnings.warn(
# Loaded from: c:\Users\user\ProgrammingProjects\Coursera\IBM_DE\ibm-data-engineering\venv312_ibmde\Lib\site-packages\airflow\sdk\__init__.py
# Has ObjectStoragePath: False
# []

# %%
import sys
for mod in list(sys.modules):
    if mod.startswith("airflow"):
        del sys.modules[mod]

from airflow.providers_manager import ProvidersManager
pm = ProvidersManager()
pm.initialize_providers_list()  # forces discovery
import json
print(json.dumps(pm.import_errors, indent=2))
# Out:
# 2026-09-04T12:59:50.277460Z [warning  ] Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority. [py.warnings] category=RuntimeWarning filename=c:\Users\user\ProgrammingProjects\Coursera\IBM_DE\ibm-data-engineering\venv312_ibmde\Lib\site-packages\airflow\__init__.py lineno=47
# 2026-09-04T12:59:50.846169Z [info     ] Reading the config from C:\Users\user/airflow\airflow.cfg [airflow.configuration] loc=configuration.py:663
# 2026-09-04T12:59:50.875177Z [info     ] Configured default timezone UTC [airflow.settings] loc=settings.py:92
# ---------------------------------------------------------------------------
# ...

# %%
import sys
for mod in list(sys.modules):
    if mod.startswith("airflow"):
        del sys.modules[mod]

from airflow.providers_manager import ProvidersManager
pm = ProvidersManager()

# Trigger discovery first — some ProvidersManager caches are lazy
_ = pm.providers

# Now inspect what's actually available on the object
attrs = [a for a in dir(pm) if "error" in a.lower()]
print(attrs)
# Out:
# 2026-09-04T05:28:01.531206Z [warning  ] Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority. [py.warnings] category=RuntimeWarning filename=c:\Users\user\ProgrammingProjects\Coursera\IBM_DE\ibm-data-engineering\venv312_ibmde\Lib\site-packages\airflow\__init__.py lineno=47
# 2026-09-04T05:28:01.688386Z [info     ] Reading the config from C:\Users\user/airflow\airflow.cfg [airflow.configuration] loc=configuration.py:663
# 2026-09-04T05:28:01.715917Z [info     ] Configured default timezone UTC [airflow.settings] loc=settings.py:92
# []
